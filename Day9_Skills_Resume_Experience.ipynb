# %% [markdown]
# # Day 9 - Skills, Resume Download & Experience Sections
#
# Codomax Web Dev Internship
#
# Today's task was to expand the Skills section with real categories, add a Resume Download button, and build out an Experience section listing my internships so far.

# %% [markdown]
# ## What I did today
#
# - reorganized Skills into categories instead of one flat grid
# - added a Resume Download button (placeholder link for now, will point to the actual PDF once it's in the repo)
# - built an Experience section listing my internships with dates
# - kept the same card/section styling from earlier days for consistency

# %% [markdown]
# ## Skills section - organized by category
#
# Instead of one grid of everything, split it into categories to match my actual resume better:
#
# ```html
# <section class="skills" id="skills">
#   <h2>Skills</h2>
#
#   <div class="skills-category">
#     <h3>Programming Languages</h3>
#     <div class="skills-grid">
#       <div class="skill-card">Python</div>
#       <div class="skill-card">C</div>
#       <div class="skill-card">Verilog</div>
#     </div>
#   </div>
#
#   <div class="skills-category">
#     <h3>Electronics</h3>
#     <div class="skills-grid">
#       <div class="skill-card">VLSI</div>
#       <div class="skill-card">Signals and Systems</div>
#       <div class="skill-card">Analog & Digital Electronics</div>
#       <div class="skill-card">Network Theory</div>
#     </div>
#   </div>
#
#   <div class="skills-category">
#     <h3>Tools & Software</h3>
#     <div class="skills-grid">
#       <div class="skill-card">MATLAB</div>
#       <div class="skill-card">Xilinx Vivado</div>
#       <div class="skill-card">PYNQ</div>
#       <div class="skill-card">LTspice</div>
#       <div class="skill-card">Electric VLSI</div>
#     </div>
#   </div>
#
# </section>
# ```
#
# ```css
# .skills-category {
#   margin-bottom: 32px;
# }
#
# .skills-category h3 {
#   margin-bottom: 12px;
#   font-size: 1.1rem;
#   color: var(--accent-color);
# }
# ```

# %% [markdown]
# ## Resume Download button
#
# ```html
# <section class="resume" id="resume">
#   <h2>Resume</h2>
#   <p>Download a copy of my full resume below.</p>
#   <a href="assets/resume.pdf" class="btn" download>Download Resume</a>
# </section>
# ```
#
# Left the `href` pointing to `assets/resume.pdf` as a placeholder path - just need to actually drop the PDF into the assets folder to make it live. The `download` attribute makes the browser download the file instead of opening it in a new tab.

# %% [markdown]
# ## Experience section
#
# ```html
# <section class="experience" id="experience">
#   <h2>Experience</h2>
#
#   <div class="experience-item">
#     <h3>Codomax Digital Solutions</h3>
#     <p class="project-meta">18 Jul 2026 - 01 Aug 2026</p>
#     <p>Web Development Internship - building a responsive personal portfolio website from scratch.</p>
#   </div>
#
#   <div class="experience-item">
#     <h3>Navodita Infotech</h3>
#     <p class="project-meta">15 Jul 2026 - 14 Aug 2026</p>
#     <p>Internship experience alongside academic coursework.</p>
#   </div>
#
#   <div class="experience-item">
#     <h3>Southern Railway</h3>
#     <p class="project-meta">16 Jun 2025 - 20 Jun 2025</p>
#     <p>Short-term internship exposure.</p>
#   </div>
#
# </section>
# ```
#
# ```css
# .experience-item {
#   max-width: 600px;
#   margin: 0 auto 24px auto;
#   padding-bottom: 16px;
#   border-bottom: 1px solid #e5e5e5;
# }
#
# .experience-item:last-child {
#   border-bottom: none;
# }
# ```
#
# Kept the layout simple - title, dates, one-line description. Didn't want to overcrowd it since the Projects section already covers the technical depth.

# %% [markdown]
# ## Things I got stuck on / figured out
#
# - had to decide how much detail to put in Experience vs Projects, ended up keeping Experience brief since Projects already goes into technical detail
# - resume download link doesn't work yet since the actual PDF isn't in the repo, noted as a to-do before final submission

# %% [markdown]
# ## Today's submissions
#
# - pushed to GitHub
# - posted on LinkedIn
# - filled the daily form
#
# Tomorrow: professional Contact page with social links and form validation.
