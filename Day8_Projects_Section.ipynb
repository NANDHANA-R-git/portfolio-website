# %% [markdown]
# # Day 8 - Projects Section
#
# Codomax Web Dev Internship
#
# Today's task was to build the Projects section with at least three project cards, reusing the same card/grid pattern from the Skills section on Day 5.

# %% [markdown]
# ## What I did today
#
# - picked 3 real projects to feature instead of placeholders
# - reused the grid layout pattern from Skills for consistency
# - added project cards with title, timeline, description and a link
# - made cards slightly interactive with a hover effect

# %% [markdown]
# ## Projects section markup
#
# ```html
# <section class="projects" id="projects">
#   <h2>Projects</h2>
#   <div class="projects-grid">
#
#     <div class="project-card">
#       <h3>FPGA Accelerated Indoor Navigation and Localization Platform</h3>
#       <p class="project-meta">Ongoing</p>
#       <p>
#         Indoor navigation system for large buildings with accessibility support
#         using multi-sensor fusion (BLE, Wi-Fi, IMU). Implemented on Xilinx
#         PYNQ-Z2 for real-time processing.
#       </p>
#       <a href="#" class="btn">View</a>
#     </div>
#
#     <div class="project-card">
#       <h3>Low Power 6T SRAM Cell - Design, Simulation & Implementation</h3>
#       <p class="project-meta">Jan 2026 - Mar 2026</p>
#       <p>
#         Designed and simulated a low-power 6T SRAM cell using LTspice and
#         Electric VLSI. Analyzed read/write stability and power consumption.
#       </p>
#       <a href="#" class="btn">View</a>
#     </div>
#
#     <div class="project-card">
#       <h3>Price Tracker</h3>
#       <p class="project-meta">July 2026</p>
#       <p>
#         Python-based tool to track e-commerce product prices and send alerts
#         via Twilio. Used Git & GitHub for version control, built in VS Code.
#       </p>
#       <a href="#" class="btn">View</a>
#     </div>
#
#   </div>
# </section>
# ```
#
# ```css
# .projects-grid {
#   display: grid;
#   grid-template-columns: repeat(3, 1fr);
#   gap: 20px;
#   max-width: 1000px;
#   margin: 0 auto;
# }
#
# .project-card {
#   background-color: var(--section-bg);
#   border: 1px solid #e5e5e5;
#   border-radius: 8px;
#   padding: 20px;
#   transition: transform 0.2s ease;
# }
#
# .project-card:hover {
#   transform: translateY(-4px);
# }
#
# .project-meta {
#   font-size: 0.85rem;
#   color: var(--accent-color);
#   font-weight: 500;
#   margin-bottom: 8px;
# }
# ```
#
# 3 columns on desktop for now, will need to drop to fewer columns on mobile/tablet using the same media query breakpoints from Day 6.

# %% [markdown]
# ## Things I got stuck on / figured out
#
# - had a bit of trouble keeping card heights consistent since the project descriptions were different lengths, ended up relying on the grid to handle alignment instead of manually setting heights
# - realized the project titles were too long for the card width on smaller screens, something to double check when I add media queries here too

# %% [markdown]
# ## Today's submissions
#
# - pushed to GitHub
# - posted on LinkedIn
# - filled the daily form
#
# Tomorrow: Skills, Resume Download and Experience sections.
