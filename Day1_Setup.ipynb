# %% [markdown]
# # Day 1 – Environment Setup & GitHub Repository Initialization
#
# **Project:** Responsive Personal Portfolio Website
# **Internship:** Codomax Digital Solutions – Web Development Internship
# **Day:** 1 of 14
#
# ---
#
# ## Objective
# Set up the local development environment and initialize the GitHub repository that will host the Responsive Personal Portfolio Website built over the next 14 days.

# %% [markdown]
# ## Tasks Completed Today
#
# - [x] Installed **VS Code**
# - [x] Installed **Git**
# - [x] Installed **Google Chrome**
# - [x] Installed VS Code extensions (Live Server, Prettier, HTML/CSS/JS support)
# - [x] Created a **GitHub account**
# - [x] Initialized a new Git repository for the portfolio project

# %% [markdown]
# ## 1. Tools Installed
#
# | Tool | Purpose |
# |------|---------|
# | VS Code | Code editor for HTML, CSS, and JavaScript |
# | Git | Version control system |
# | Chrome | Browser for testing and DevTools |
# | Live Server (extension) | Local live-reloading dev server |
# | Prettier (extension) | Automatic code formatting |

# %% [markdown]
# ## 2. GitHub Account & Repository
#
# - Created a personal GitHub account
# - Created a new repository named `portfolio-website`
# - Cloned it locally and set it as the working project folder

# %% [markdown]
# ## 3. Git Commands Used
#
# ```bash
# # Configure Git identity (one-time setup)
# git config --global user.name "Your Name"
# git config --global user.email "you@example.com"
#
# # Initialize repository
# git init
#
# # Create a basic README
# echo "# Responsive Personal Portfolio Website" > README.md
#
# # Stage and commit
# git add .
# git commit -m "Day 1: Initialize repository and project setup"
#
# # Connect to GitHub remote and push
# git remote add origin https://github.com/<your-username>/portfolio-website.git
# git branch -M main
# git push -u origin main
# ```

# %% [markdown]
# ## 4. Folder Structure Created
#
# ```
# portfolio-website/
# │
# ├── index.html
# ├── css/
# │   └── style.css
# ├── js/
# │   └── script.js
# ├── assets/
# │   └── images/
# └── README.md
# ```

# %% [markdown]
# ## 5. Learnings
#
# - Understood the role of Git for version control and GitHub for hosting/collaboration.
# - Learned the difference between `git init`, `git add`, `git commit`, and `git push`.
# - Set up a clean, organized folder structure to scale the project over the next 14 days.
# - Configured VS Code extensions to speed up HTML/CSS/JS development.

# %% [markdown]
# ## 6. Daily Deliverables
#
# - [x] GitHub commit — "Day 1: Initialize repository and project setup"
# - [x] LinkedIn post about starting the internship journey
# - [x] Google Form submission with GitHub + LinkedIn links
#
# ---
# *Next: Day 2 – Learn HTML basics and build the Home, Hero, and About sections.*
